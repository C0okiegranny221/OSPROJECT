# %% [markdown]
# # Implementation: Collect Process Data

# %%
# !pip install psutil pandas scikit-learn joblib stable-baselines3 gymnasium
# Out:
# Requirement already satisfied: psutil in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (6.1.1)
# Requirement already satisfied: pandas in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: joblib in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: stable-baselines3 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: gymnasium in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (2.6.0)
# Requirement already satisfied: cloudpickle in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: matplotlib in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: six>=1.5 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: filelock in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (3.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aryansahni/miniforge3/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)

# %%
import psutil
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import joblib
from queue import Queue
import time
import threading
import os

# %%
def get_process_data():
    process_list = []
    
    for proc in psutil.process_iter(['pid', 'cpu_times', 'memory_info', 'nice']):
        try:
            info = proc.info
            process_list.append({
                "pid": info['pid'],
                "utime": info['cpu_times'].user if info['cpu_times'] else 0,  
                "stime": info['cpu_times'].system if info['cpu_times'] else 0, 
                "priority": info['nice'],  
                "mem_usage": info['memory_info'].rss if info['memory_info'] else 0  
            })
        except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
            continue
    
    return pd.DataFrame(process_list)


df = get_process_data()
df["process_type"] = df["utime"] > df["stime"] 
df.to_csv("windows_process_data.csv", index=False)
df.head()
# Out:
#    pid  utime  stime  priority  mem_usage  process_type
# 0    0    0.0    0.0         0          0         False
# 1    1    0.0    0.0         0          0         False
# 2  505    0.0    0.0         0          0         False
# 3  506    0.0    0.0         0          0         False
# 4  507    0.0    0.0         0          0         False

# %%
# 📌 Step 4: Train an AI Model for Process Classification


X = df[["utime", "stime", "priority", "mem_usage"]]
y = df["process_type"]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, y_train)


joblib.dump(model, "process_classifier.pkl")

print("✅ Model trained and saved as process_classifier.pkl")
# Out:
# ✅ Model trained and saved as process_classifier.pkl

# %%
df.head()
# Out:
#    pid  utime  stime  priority  mem_usage  process_type
# 0    0    0.0    0.0         0          0         False
# 1    1    0.0    0.0         0          0         False
# 2  505    0.0    0.0         0          0         False
# 3  506    0.0    0.0         0          0         False
# 4  507    0.0    0.0         0          0         False

# %% [markdown]
# # REINFORCEMENT LEARNING FOR INTERNAL QUEUE LOGIC

# %%
import threading
import time
import csv
import psutil
import pandas as pd
import joblib
import numpy as np
from queue import Queue
from stable_baselines3 import PPO

# Load trained RL model
rl_model = PPO.load("rl_scheduler_model.zip")
model = joblib.load("process_classifier.pkl")  # ML model for classification

# Define Queues
cpu_queue = Queue()
io_queue = Queue()
processed_pids = set()
running = True
last_action = None

# RL Metrics Dictionary
rl_metrics = {
    "decision_steps": 0,
    "total_reward": 0,
    "action_counts": {"PROCESS_CPU": 0, "PROCESS_IO": 0},
    "completed_tasks": {"CPU": 0, "IO": 0}
}
count = 0
def rl_decision(state):
    global count
    state_array = np.array([state['CPU_QUEUE_SIZE'], state['IO_QUEUE_SIZE']], dtype=np.float32).reshape(1, -1)
    action, _ = rl_model.predict(state_array, deterministic=True) 
    if count == 3:
        count = 0
        return 'PROCESS_IO'
    elif action == 0:
        count+=1
        return 'PROCESS_CPU'
    else:
        'PROCESS_IO'

def classify_and_enqueue():
    global processed_pids, running
    while running:
        for proc in psutil.process_iter(['pid']):
            if not running:
                break
            try:
                pid = proc.info['pid']
                if pid in processed_pids:
                    continue
                process_data = pd.DataFrame([{
                    "utime": proc.cpu_times().user if proc.cpu_times() else 0,
                    "stime": proc.cpu_times().system if proc.cpu_times() else 0,
                    "priority": proc.nice(),
                    "mem_usage": proc.memory_info().rss if proc.memory_info() else 0
                }])
                prediction = model.predict(process_data)[0]
                if prediction:
                    cpu_queue.put(pid)
                else:
                    io_queue.put(pid)
                processed_pids.add(pid)
            except (psutil.NoSuchProcess, psutil.AccessDenied):
                continue
        time.sleep(5)

def process_queue(q, queue_type, execution_time=2):
    global processed_pids, running
    while running:
        if not q.empty():
            pid = q.get()
            if not psutil.pid_exists(pid):
                continue
            print(f"Processing {queue_type} task: PID {pid}")
            time.sleep(execution_time)
            processed_pids.discard(pid)
            q.task_done()
            print(f"Completed {queue_type} task: PID {pid}")

def get_reward(state, last_action):
    cpu_load = psutil.cpu_percent(interval=1)
    io_load = psutil.disk_io_counters().read_bytes
    reward = 0
    if last_action == "PROCESS_CPU":
        reward += 10 if cpu_load < 50 else -10
        reward += 5 if state['CPU_QUEUE_SIZE'] < 50 else -5
    if last_action == "PROCESS_IO":
        reward += 15 if io_load < 500000 else -10
        reward += 5 if state['IO_QUEUE_SIZE'] < 30 else -5
    return reward

def update_rl_metrics(action, reward):
    rl_metrics["total_reward"] += reward
    rl_metrics["decision_steps"] += 1
    rl_metrics["action_counts"][action] += 1

def schedule_and_manage_queues():
    global running, last_action
    while running:
        state = {
            'CPU_QUEUE_SIZE': cpu_queue.qsize(),
            'IO_QUEUE_SIZE': io_queue.qsize()
        }
        action = rl_decision(state)
        if action == 'PROCESS_CPU' and not cpu_queue.empty():
            pid = cpu_queue.get()
            print(f"RL Action: Processing CPU task with PID {pid}")
            time.sleep(0.2)
            cpu_queue.task_done()
            reward = get_reward(state, last_action)
            update_rl_metrics("PROCESS_CPU", reward)
            last_action = 'PROCESS_CPU'
        elif action == 'PROCESS_IO' and not io_queue.empty():
            pid = io_queue.get()
            print(f"RL Action: Processing I/O task with PID {pid}")
            time.sleep(0.1)
            io_queue.task_done()
            reward = get_reward(state, last_action)
            update_rl_metrics("PROCESS_IO", reward)
            last_action = 'PROCESS_IO'
        time.sleep(0.2)

def log_rl_metrics():
    with open("rl_metrics_log.csv", "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Time", "Steps", "PROCESS_CPU", "PROCESS_IO", "Total Reward", "Avg Reward", "CPU Queue", "IO Queue"])
    while running:
        avg_reward = rl_metrics["total_reward"] / rl_metrics["decision_steps"] if rl_metrics["decision_steps"] > 0 else 0
        with open("rl_metrics_log.csv", "a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([
                time.strftime("%H:%M:%S"), rl_metrics["decision_steps"], 
                rl_metrics["action_counts"]["PROCESS_CPU"], 
                rl_metrics["action_counts"]["PROCESS_IO"],
                rl_metrics["total_reward"], avg_reward,
                cpu_queue.qsize(), io_queue.qsize()
            ])
        time.sleep(5)

cpu_worker = threading.Thread(target=process_queue, args=(cpu_queue, "CPU-bound", 2), daemon=True)
io_worker = threading.Thread(target=process_queue, args=(io_queue, "I/O-bound", 1), daemon=True)
classifier_thread = threading.Thread(target=classify_and_enqueue, daemon=True)
scheduler_thread = threading.Thread(target=schedule_and_manage_queues, daemon=True)
log_metrics_thread = threading.Thread(target=log_rl_metrics, daemon=True)

cpu_worker.start()
io_worker.start()
classifier_thread.start()
scheduler_thread.start()
log_metrics_thread.start()

try:
    while True:
        print(f"CPU Queue Size: {cpu_queue.qsize()} | IO Queue Size: {io_queue.qsize()}")
        time.sleep(5)
except KeyboardInterrupt:
    print("\nStopping program...")
    running = False
    classifier_thread.join()
    cpu_worker.join()
    io_worker.join()
    scheduler_thread.join()
    log_metrics_thread.join()
    print("All threads stopped.")
# Out:
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing CPU-bound task: PID 577
# Processing I/O-bound task: PID 824
# RL Action: Processing CPU task with PID 804
# Completed I/O-bound task: PID 824
# Processing I/O-bound task: PID 835
# RL Action: Processing CPU task with PID 805
# Completed CPU-bound task: PID 577
# Processing CPU-bound task: PID 810
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 843
# Completed I/O-bound task: PID 843
# Processing I/O-bound task: PID 844
# RL Action: Processing CPU task with PID 811
# Completed CPU-bound task: PID 810
# Processing CPU-bound task: PID 814
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 857
# RL Action: Processing I/O task with PID 861
# CPU Queue Size: 434 | IO Queue Size: 58
# Completed I/O-bound task: PID 857
# Processing I/O-bound task: PID 873
# RL Action: Processing CPU task with PID 816
# Completed CPU-bound task: PID 814
# Processing CPU-bound task: PID 817
# Completed I/O-bound task: PID 873
# Processing I/O-bound task: PID 877
# Completed I/O-bound task: PID 877
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 819
# Completed CPU-bound task: PID 817
# Processing CPU-bound task: PID 820
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 901
# RL Action: Processing CPU task with PID 821
# Completed I/O-bound task: PID 901
# Processing I/O-bound task: PID 921
# CPU Queue Size: 434 | IO Queue Size: 59
# Completed CPU-bound task: PID 820
# Processing CPU-bound task: PID 822
# RL Action: Processing I/O task with PID 924
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 927
# Completed I/O-bound task: PID 927
# Processing I/O-bound task: PID 932
# RL Action: Processing CPU task with PID 823
# Completed CPU-bound task: PID 822
# Processing CPU-bound task: PID 826
# Completed I/O-bound task: PID 932
# Processing I/O-bound task: PID 939
# RL Action: Processing CPU task with PID 827
# Completed I/O-bound task: PID 939
# Processing I/O-bound task: PID 951
# Completed CPU-bound task: PID 826
# Processing CPU-bound task: PID 828
# Completed I/O-bound task: PID 951
# Processing I/O-bound task: PID 1065
# RL Action: Processing CPU task with PID 829
# CPU Queue Size: 431 | IO Queue Size: 58
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# RL Action: Processing I/O task with PID 1081
# Completed CPU-bound task: PID 828
# Processing CPU-bound task: PID 833
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1111
# RL Action: Processing CPU task with PID 836
# Completed I/O-bound task: PID 1111
# Processing I/O-bound task: PID 1112
# Completed CPU-bound task: PID 833
# Processing CPU-bound task: PID 837
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# RL Action: Processing CPU task with PID 838
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1132
# RL Action: Processing CPU task with PID 839
# CPU Queue Size: 429 | IO Queue Size: 57
# Completed CPU-bound task: PID 837
# Processing CPU-bound task: PID 842
# Completed I/O-bound task: PID 1132
# Processing I/O-bound task: PID 1147
# Completed I/O-bound task: PID 1147
# Processing I/O-bound task: PID 1236
# RL Action: Processing I/O task with PID 1273
# Completed CPU-bound task: PID 842
# Processing CPU-bound task: PID 845
# Completed I/O-bound task: PID 1236
# Processing I/O-bound task: PID 1283
# RL Action: Processing CPU task with PID 846
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1316
# RL Action: Processing CPU task with PID 849
# Completed CPU-bound task: PID 845
# Processing CPU-bound task: PID 851
# Completed I/O-bound task: PID 1316
# Processing I/O-bound task: PID 1322
# CPU Queue Size: 427 | IO Queue Size: 56
# Completed I/O-bound task: PID 1322
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 852
# Completed CPU-bound task: PID 851
# Processing CPU-bound task: PID 853
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1341
# RL Action: Processing I/O task with PID 1405
# Completed I/O-bound task: PID 1341
# Processing I/O-bound task: PID 1507
# Completed CPU-bound task: PID 853
# Processing CPU-bound task: PID 855
# RL Action: Processing CPU task with PID 858
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1607
# Completed I/O-bound task: PID 1607
# Processing I/O-bound task: PID 1752
# RL Action: Processing CPU task with PID 859
# CPU Queue Size: 427 | IO Queue Size: 55
# Completed CPU-bound task: PID 855
# Processing CPU-bound task: PID 860
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 862
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 1860
# Completed CPU-bound task: PID 860
# Processing CPU-bound task: PID 863
# Completed I/O-bound task: PID 1860
# Processing I/O-bound task: PID 1926
# RL Action: Processing I/O task with PID 1948
# Completed I/O-bound task: PID 1926
# Processing I/O-bound task: PID 2001
# RL Action: Processing CPU task with PID 864
# Completed CPU-bound task: PID 863
# Processing CPU-bound task: PID 865
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2002
# CPU Queue Size: 424 | IO Queue Size: 54
# RL Action: Processing CPU task with PID 867
# Completed I/O-bound task: PID 2002
# Processing I/O-bound task: PID 2057
# Completed CPU-bound task: PID 865
# Processing CPU-bound task: PID 868
# Completed I/O-bound task: PID 2057
# Processing I/O-bound task: PID 2058
# RL Action: Processing CPU task with PID 870
# Completed I/O-bound task: PID 2058
# Processing I/O-bound task: PID 2084
# RL Action: Processing I/O task with PID 3286
# Completed CPU-bound task: PID 868
# Processing CPU-bound task: PID 871
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 872
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 7794
# CPU Queue Size: 422 | IO Queue Size: 53
# Completed CPU-bound task: PID 871
# Processing CPU-bound task: PID 874
# Completed I/O-bound task: PID 7794
# Processing I/O-bound task: PID 7796
# RL Action: Processing CPU task with PID 878
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 8038
# RL Action: Processing CPU task with PID 879
# Completed CPU-bound task: PID 874
# Processing CPU-bound task: PID 881
# Completed I/O-bound task: PID 8038
# Processing I/O-bound task: PID 8128
# Completed I/O-bound task: PID 8128
# Processing I/O-bound task: PID 8339
# RL Action: Processing I/O task with PID 8387
# Completed CPU-bound task: PID 881
# Processing CPU-bound task: PID 882
# Completed I/O-bound task: PID 8339
# Processing I/O-bound task: PID 9736
# RL Action: Processing CPU task with PID 883
# CPU Queue Size: 419 | IO Queue Size: 52
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# Completed CPU-bound task: PID 882
# Processing CPU-bound task: PID 884
# RL Action: Processing CPU task with PID 886
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 9749
# Completed I/O-bound task: PID 9749
# Processing I/O-bound task: PID 31238
# RL Action: Processing CPU task with PID 889
# Completed CPU-bound task: PID 884
# Processing CPU-bound task: PID 890
# Completed I/O-bound task: PID 31238
# Processing I/O-bound task: PID 31930
# RL Action: Processing I/O task with PID 31932
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# CPU Queue Size: 418 | IO Queue Size: 51
# Completed CPU-bound task: PID 890
# Processing CPU-bound task: PID 891
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 37189
# RL Action: Processing CPU task with PID 892
# Completed I/O-bound task: PID 37189
# Processing I/O-bound task: PID 39347
# RL Action: Processing CPU task with PID 893
# Completed CPU-bound task: PID 891
# Processing CPU-bound task: PID 894
# Completed I/O-bound task: PID 39347
# Processing I/O-bound task: PID 40110
# RL Action: Processing CPU task with PID 895
# Completed I/O-bound task: PID 40110
# Processing I/O-bound task: PID 40797
# Completed CPU-bound task: PID 894
# Processing CPU-bound task: PID 896
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# RL Action: Processing I/O task with PID 824
# CPU Queue Size: 414 | IO Queue Size: 50
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 835
# RL Action: Processing CPU task with PID 897
# Completed CPU-bound task: PID 896
# Processing CPU-bound task: PID 902
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 843
# RL Action: Processing CPU task with PID 910
# Completed I/O-bound task: PID 843
# Processing I/O-bound task: PID 844
# Completed CPU-bound task: PID 902
# Processing CPU-bound task: PID 911
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 857
# RL Action: Processing CPU task with PID 912
# Completed I/O-bound task: PID 857
# Processing I/O-bound task: PID 873
# CPU Queue Size: 414 | IO Queue Size: 50
# Completed CPU-bound task: PID 911
# Processing CPU-bound task: PID 915
# RL Action: Processing I/O task with PID 877
# Completed I/O-bound task: PID 873
# Processing I/O-bound task: PID 888
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 901
# RL Action: Processing CPU task with PID 918
# Completed CPU-bound task: PID 915
# Processing CPU-bound task: PID 919
# Completed I/O-bound task: PID 901
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 925
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 927
# Completed CPU-bound task: PID 919
# Processing CPU-bound task: PID 928
# RL Action: Processing CPU task with PID 931
# Completed I/O-bound task: PID 927
# Processing I/O-bound task: PID 932
# CPU Queue Size: 411 | IO Queue Size: 49
# Completed I/O-bound task: PID 932
# Processing I/O-bound task: PID 939
# RL Action: Processing I/O task with PID 951
# Completed CPU-bound task: PID 928
# Processing CPU-bound task: PID 934
# Completed I/O-bound task: PID 939
# Processing I/O-bound task: PID 1065
# RL Action: Processing CPU task with PID 935
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# Completed CPU-bound task: PID 934
# Processing CPU-bound task: PID 936
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1111
# RL Action: Processing CPU task with PID 937
# Completed I/O-bound task: PID 1111
# Processing I/O-bound task: PID 1112
# RL Action: Processing CPU task with PID 940
# CPU Queue Size: 410 | IO Queue Size: 48
# Completed CPU-bound task: PID 936
# Processing CPU-bound task: PID 941
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# RL Action: Processing I/O task with PID 1132
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1147
# Completed CPU-bound task: PID 941
# Processing CPU-bound task: PID 942
# Completed I/O-bound task: PID 1147
# Processing I/O-bound task: PID 1236
# RL Action: Processing CPU task with PID 944
# Completed I/O-bound task: PID 1236
# Processing I/O-bound task: PID 1283
# RL Action: Processing CPU task with PID 945
# Completed CPU-bound task: PID 942
# Processing CPU-bound task: PID 946
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1316
# CPU Queue Size: 408 | IO Queue Size: 47
# RL Action: Processing CPU task with PID 948
# Completed I/O-bound task: PID 1316
# Processing I/O-bound task: PID 1322
# Completed CPU-bound task: PID 946
# Processing CPU-bound task: PID 956
# Completed I/O-bound task: PID 1322
# Processing I/O-bound task: PID 1325
# RL Action: Processing I/O task with PID 1341
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# RL Action: Processing CPU task with PID 959
# Completed CPU-bound task: PID 956
# Processing CPU-bound task: PID 960
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1607
# Completed I/O-bound task: PID 1607
# Processing I/O-bound task: PID 1752
# RL Action: Processing CPU task with PID 961
# CPU Queue Size: 405 | IO Queue Size: 46
# Completed CPU-bound task: PID 960
# Processing CPU-bound task: PID 962
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 963
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 1860
# Completed CPU-bound task: PID 962
# Processing CPU-bound task: PID 965
# RL Action: Processing I/O task with PID 1926
# Completed I/O-bound task: PID 1860
# Processing I/O-bound task: PID 2001
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2002
# RL Action: Processing CPU task with PID 968
# Completed CPU-bound task: PID 965
# Processing CPU-bound task: PID 970
# Completed I/O-bound task: PID 2002
# Processing I/O-bound task: PID 2057
# CPU Queue Size: 404 | IO Queue Size: 45
# RL Action: Processing CPU task with PID 971
# Completed I/O-bound task: PID 2057
# Processing I/O-bound task: PID 2058
# Completed CPU-bound task: PID 970
# Processing CPU-bound task: PID 974
# Completed I/O-bound task: PID 2058
# Processing I/O-bound task: PID 2084
# RL Action: Processing CPU task with PID 983
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing I/O task with PID 7794
# Completed CPU-bound task: PID 974
# Processing CPU-bound task: PID 1049
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 7796
# RL Action: Processing CPU task with PID 1058
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 8038
# CPU Queue Size: 405 | IO Queue Size: 50
# Completed CPU-bound task: PID 1049
# Processing CPU-bound task: PID 1059
# Completed I/O-bound task: PID 8038
# Processing I/O-bound task: PID 8128
# RL Action: Processing CPU task with PID 1060
# Completed I/O-bound task: PID 8128
# Processing I/O-bound task: PID 8339
# RL Action: Processing CPU task with PID 1061
# Completed CPU-bound task: PID 1059
# Processing CPU-bound task: PID 1063
# Completed I/O-bound task: PID 8339
# Processing I/O-bound task: PID 9736
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# RL Action: Processing I/O task with PID 9749
# Completed CPU-bound task: PID 1063
# Processing CPU-bound task: PID 1066
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 31238
# RL Action: Processing CPU task with PID 1067
# CPU Queue Size: 403 | IO Queue Size: 50
# Completed I/O-bound task: PID 31238
# Processing I/O-bound task: PID 31930
# Completed CPU-bound task: PID 1066
# Processing CPU-bound task: PID 1068
# RL Action: Processing CPU task with PID 1069
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 37189
# RL Action: Processing CPU task with PID 1073
# Completed CPU-bound task: PID 1068
# Processing CPU-bound task: PID 1074
# Completed I/O-bound task: PID 37189
# Processing I/O-bound task: PID 835
# RL Action: Processing I/O task with PID 39347
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 40110
# CPU Queue Size: 401 | IO Queue Size: 49
# Completed CPU-bound task: PID 1074
# Processing CPU-bound task: PID 1080
# RL Action: Processing CPU task with PID 1083
# Completed I/O-bound task: PID 40110
# Processing I/O-bound task: PID 40797
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# RL Action: Processing CPU task with PID 1084
# Completed CPU-bound task: PID 1080
# Processing CPU-bound task: PID 1087
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 843
# RL Action: Processing CPU task with PID 1088
# Completed I/O-bound task: PID 843
# Processing I/O-bound task: PID 844
# Completed CPU-bound task: PID 1087
# Processing CPU-bound task: PID 1090
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 857
# RL Action: Processing I/O task with PID 873
# CPU Queue Size: 398 | IO Queue Size: 48
# Completed I/O-bound task: PID 857
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 1091
# Completed CPU-bound task: PID 1090
# Processing CPU-bound task: PID 1092
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 901
# RL Action: Processing CPU task with PID 1093
# Completed I/O-bound task: PID 901
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 1092
# Processing CPU-bound task: PID 1094
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 927
# RL Action: Processing CPU task with PID 1095
# Completed I/O-bound task: PID 927
# Processing I/O-bound task: PID 932
# CPU Queue Size: 395 | IO Queue Size: 48
# RL Action: Processing I/O task with PID 939
# Completed CPU-bound task: PID 1094
# Processing CPU-bound task: PID 1108
# Completed I/O-bound task: PID 932
# Processing I/O-bound task: PID 1065
# RL Action: Processing CPU task with PID 1110
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# Completed CPU-bound task: PID 1108
# Processing CPU-bound task: PID 1114
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1111
# RL Action: Processing CPU task with PID 1115
# Completed I/O-bound task: PID 1111
# Processing I/O-bound task: PID 1112
# Completed CPU-bound task: PID 1114
# Processing CPU-bound task: PID 1116
# RL Action: Processing CPU task with PID 1117
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# CPU Queue Size: 394 | IO Queue Size: 46
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1147
# RL Action: Processing I/O task with PID 1236
# Completed CPU-bound task: PID 1116
# Processing CPU-bound task: PID 1118
# Completed I/O-bound task: PID 1147
# Processing I/O-bound task: PID 1283
# RL Action: Processing CPU task with PID 1119
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1316
# Completed CPU-bound task: PID 1118
# Processing CPU-bound task: PID 1120
# RL Action: Processing CPU task with PID 1121
# Completed I/O-bound task: PID 1316
# Processing I/O-bound task: PID 1322
# Completed I/O-bound task: PID 1322
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 1122
# CPU Queue Size: 393 | IO Queue Size: 45
# Completed CPU-bound task: PID 1120
# Processing CPU-bound task: PID 1127
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# RL Action: Processing I/O task with PID 1607
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1752
# Completed CPU-bound task: PID 1127
# Processing CPU-bound task: PID 1128
# RL Action: Processing CPU task with PID 1129
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 1860
# RL Action: Processing CPU task with PID 1130
# Completed CPU-bound task: PID 1128
# Processing CPU-bound task: PID 1131
# Completed I/O-bound task: PID 1860
# Processing I/O-bound task: PID 2001
# CPU Queue Size: 393 | IO Queue Size: 44
# RL Action: Processing CPU task with PID 1133
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2002
# Completed CPU-bound task: PID 1131
# Processing CPU-bound task: PID 1136
# Completed I/O-bound task: PID 2002
# Processing I/O-bound task: PID 2057
# RL Action: Processing I/O task with PID 2058
# Completed I/O-bound task: PID 2057
# Processing I/O-bound task: PID 2084
# RL Action: Processing CPU task with PID 1137
# Completed CPU-bound task: PID 1136
# Processing CPU-bound task: PID 1140
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 1143
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 7796
# CPU Queue Size: 390 | IO Queue Size: 37
# Completed CPU-bound task: PID 1140
# Processing CPU-bound task: PID 1145
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 8038
# RL Action: Processing CPU task with PID 1150
# Completed I/O-bound task: PID 8038
# Processing I/O-bound task: PID 8128
# Completed CPU-bound task: PID 1145
# Processing CPU-bound task: PID 1151
# RL Action: Processing I/O task with PID 8339
# Completed I/O-bound task: PID 8128
# Processing I/O-bound task: PID 9736
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# RL Action: Processing CPU task with PID 1153
# Completed CPU-bound task: PID 1151
# Processing CPU-bound task: PID 1156
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 31238
# RL Action: Processing CPU task with PID 1161
# CPU Queue Size: 387 | IO Queue Size: 36
# Completed I/O-bound task: PID 31238
# Processing I/O-bound task: PID 31930
# Completed CPU-bound task: PID 1156
# Processing CPU-bound task: PID 1170
# RL Action: Processing CPU task with PID 1172
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 835
# RL Action: Processing I/O task with PID 37189
# Completed CPU-bound task: PID 1170
# Processing CPU-bound task: PID 1174
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 40110
# RL Action: Processing CPU task with PID 1175
# Completed I/O-bound task: PID 40110
# Processing I/O-bound task: PID 40797
# CPU Queue Size: 386 | IO Queue Size: 35
# Completed CPU-bound task: PID 1174
# Processing CPU-bound task: PID 1178
# RL Action: Processing CPU task with PID 1181
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 843
# RL Action: Processing CPU task with PID 1183
# Completed CPU-bound task: PID 1178
# Processing CPU-bound task: PID 1185
# Completed I/O-bound task: PID 843
# Processing I/O-bound task: PID 844
# RL Action: Processing I/O task with PID 857
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 1185
# Processing CPU-bound task: PID 1186
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 901
# RL Action: Processing CPU task with PID 1187
# CPU Queue Size: 383 | IO Queue Size: 34
# Completed I/O-bound task: PID 901
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1188
# Completed CPU-bound task: PID 1186
# Processing CPU-bound task: PID 1189
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 927
# RL Action: Processing CPU task with PID 1190
# Completed I/O-bound task: PID 927
# Processing I/O-bound task: PID 1065
# Completed CPU-bound task: PID 1189
# Processing CPU-bound task: PID 1191
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# RL Action: Processing I/O task with PID 1111
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# CPU Queue Size: 381 | IO Queue Size: 33
# Completed CPU-bound task: PID 1191
# Processing CPU-bound task: PID 1192
# RL Action: Processing CPU task with PID 1193
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1147
# RL Action: Processing CPU task with PID 1194
# Completed CPU-bound task: PID 1192
# Processing CPU-bound task: PID 1195
# Completed I/O-bound task: PID 1147
# Processing I/O-bound task: PID 1283
# RL Action: Processing CPU task with PID 1196
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1316
# Completed CPU-bound task: PID 1195
# Processing CPU-bound task: PID 1197
# RL Action: Processing I/O task with PID 1322
# Completed I/O-bound task: PID 1316
# Processing I/O-bound task: PID 1325
# CPU Queue Size: 378 | IO Queue Size: 32
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# RL Action: Processing CPU task with PID 1198
# Completed CPU-bound task: PID 1197
# Processing CPU-bound task: PID 1200
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1752
# RL Action: Processing CPU task with PID 1201
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# Completed CPU-bound task: PID 1200
# Processing CPU-bound task: PID 1204
# RL Action: Processing CPU task with PID 1205
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 1860
# Completed I/O-bound task: PID 1860
# Processing I/O-bound task: PID 2001
# CPU Queue Size: 376 | IO Queue Size: 32
# RL Action: Processing I/O task with PID 2002
# Completed CPU-bound task: PID 1204
# Processing CPU-bound task: PID 1206
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2057
# RL Action: Processing CPU task with PID 1207
# Completed I/O-bound task: PID 2057
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 1206
# Processing CPU-bound task: PID 1209
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 1211
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 7796
# RL Action: Processing CPU task with PID 1212
# Completed CPU-bound task: PID 1209
# Processing CPU-bound task: PID 1213
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 8038
# CPU Queue Size: 372 | IO Queue Size: 31
# RL Action: Processing I/O task with PID 8128
# Completed I/O-bound task: PID 8038
# Processing I/O-bound task: PID 9736
# Completed CPU-bound task: PID 1213
# Processing CPU-bound task: PID 1214
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# RL Action: Processing CPU task with PID 1216
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 31238
# Completed CPU-bound task: PID 1214
# Processing CPU-bound task: PID 1217
# RL Action: Processing CPU task with PID 1219
# Completed I/O-bound task: PID 31238
# Processing I/O-bound task: PID 31930
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# RL Action: Processing CPU task with PID 1220
# CPU Queue Size: 370 | IO Queue Size: 30
# Completed CPU-bound task: PID 1217
# Processing CPU-bound task: PID 1224
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 835
# RL Action: Processing I/O task with PID 843
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 40110
# Completed CPU-bound task: PID 1224
# Processing CPU-bound task: PID 1230
# RL Action: Processing CPU task with PID 1238
# Completed I/O-bound task: PID 40110
# Processing I/O-bound task: PID 40797
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# RL Action: Processing CPU task with PID 1239
# Completed CPU-bound task: PID 1230
# Processing CPU-bound task: PID 1240
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 844
# CPU Queue Size: 367 | IO Queue Size: 29
# RL Action: Processing CPU task with PID 1241
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 1240
# Processing CPU-bound task: PID 1242
# RL Action: Processing I/O task with PID 901
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 927
# RL Action: Processing CPU task with PID 1244
# Completed CPU-bound task: PID 1242
# Processing CPU-bound task: PID 1245
# Completed I/O-bound task: PID 927
# Processing I/O-bound task: PID 1065
# RL Action: Processing CPU task with PID 1247
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# CPU Queue Size: 365 | IO Queue Size: 28
# Completed CPU-bound task: PID 1245
# Processing CPU-bound task: PID 1248
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# RL Action: Processing CPU task with PID 1249
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# RL Action: Processing I/O task with PID 1147
# Completed CPU-bound task: PID 1248
# Processing CPU-bound task: PID 1254
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1283
# RL Action: Processing CPU task with PID 1264
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1316
# Completed CPU-bound task: PID 1254
# Processing CPU-bound task: PID 1265
# Completed I/O-bound task: PID 1316
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 1266
# CPU Queue Size: 361 | IO Queue Size: 27
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# Completed CPU-bound task: PID 1265
# Processing CPU-bound task: PID 1269
# RL Action: Processing CPU task with PID 1270
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1752
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# RL Action: Processing I/O task with PID 1860
# Completed CPU-bound task: PID 1269
# Processing CPU-bound task: PID 1271
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2001
# RL Action: Processing CPU task with PID 1276
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2057
# CPU Queue Size: 359 | IO Queue Size: 27
# Completed CPU-bound task: PID 1271
# Processing CPU-bound task: PID 1280
# RL Action: Processing CPU task with PID 1281
# Completed I/O-bound task: PID 2057
# Processing I/O-bound task: PID 2084
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 1282
# Completed CPU-bound task: PID 1280
# Processing CPU-bound task: PID 1284
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 7796
# RL Action: Processing I/O task with PID 8038
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 9736
# Completed CPU-bound task: PID 1284
# Processing CPU-bound task: PID 1285
# RL Action: Processing CPU task with PID 1286
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# CPU Queue Size: 355 | IO Queue Size: 26
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 835
# RL Action: Processing CPU task with PID 1288
# Completed CPU-bound task: PID 1285
# Processing CPU-bound task: PID 1290
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 31238
# RL Action: Processing CPU task with PID 1294
# Completed I/O-bound task: PID 31238
# Processing I/O-bound task: PID 31930
# Completed CPU-bound task: PID 1290
# Processing CPU-bound task: PID 1301
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# RL Action: Processing I/O task with PID 40110
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 844
# CPU Queue Size: 354 | IO Queue Size: 25
# RL Action: Processing CPU task with PID 1302
# Completed CPU-bound task: PID 1301
# Processing CPU-bound task: PID 1307
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 1310
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 1307
# Processing CPU-bound task: PID 1321
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 40797
# RL Action: Processing CPU task with PID 1328
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# Completed CPU-bound task: PID 1321
# Processing CPU-bound task: PID 1330
# RL Action: Processing I/O task with PID 927
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 1065
# CPU Queue Size: 350 | IO Queue Size: 24
# RL Action: Processing CPU task with PID 1336
# Completed I/O-bound task: PID 1065
# Processing I/O-bound task: PID 1072
# Completed CPU-bound task: PID 1330
# Processing CPU-bound task: PID 1339
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# RL Action: Processing CPU task with PID 1344
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1113
# Completed CPU-bound task: PID 1339
# Processing CPU-bound task: PID 1352
# RL Action: Processing CPU task with PID 1364
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1254
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1283
# CPU Queue Size: 348 | IO Queue Size: 24
# RL Action: Processing I/O task with PID 1316
# Completed CPU-bound task: PID 1352
# Processing CPU-bound task: PID 1368
# Completed I/O-bound task: PID 1283
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 1380
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# Completed CPU-bound task: PID 1368
# Processing CPU-bound task: PID 1381
# RL Action: Processing CPU task with PID 1385
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1752
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 1390
# Completed CPU-bound task: PID 1381
# Processing CPU-bound task: PID 1407
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2001
# CPU Queue Size: 344 | IO Queue Size: 24
# RL Action: Processing I/O task with PID 2057
# Completed I/O-bound task: PID 2001
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 1407
# Processing CPU-bound task: PID 1408
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 1418
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 835
# RL Action: Processing CPU task with PID 1425
# Completed CPU-bound task: PID 1408
# Processing CPU-bound task: PID 1429
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 7796
# RL Action: Processing CPU task with PID 1496
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 9736
# CPU Queue Size: 344 | IO Queue Size: 23
# Completed CPU-bound task: PID 1429
# Processing CPU-bound task: PID 1498
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 9737
# RL Action: Processing I/O task with PID 31238
# Completed I/O-bound task: PID 9737
# Processing I/O-bound task: PID 844
# Completed CPU-bound task: PID 1498
# Processing CPU-bound task: PID 1564
# RL Action: Processing CPU task with PID 1567
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 1568
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 1564
# Processing CPU-bound task: PID 1595
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 31930
# CPU Queue Size: 344 | IO Queue Size: 22
# RL Action: Processing CPU task with PID 1597
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# Completed CPU-bound task: PID 1595
# Processing CPU-bound task: PID 1608
# RL Action: Processing I/O task with PID 1065
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 1072
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# RL Action: Processing CPU task with PID 1611
# Completed CPU-bound task: PID 1608
# Processing CPU-bound task: PID 1617
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 40797
# RL Action: Processing CPU task with PID 1618
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# CPU Queue Size: 344 | IO Queue Size: 21
# Completed CPU-bound task: PID 1617
# Processing CPU-bound task: PID 1625
# RL Action: Processing CPU task with PID 1633
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 1113
# Completed I/O-bound task: PID 1113
# Processing I/O-bound task: PID 1254
# RL Action: Processing I/O task with PID 1283
# Completed CPU-bound task: PID 1625
# Processing CPU-bound task: PID 1730
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 1731
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 1507
# Completed CPU-bound task: PID 1730
# Processing CPU-bound task: PID 1746
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1752
# RL Action: Processing CPU task with PID 1861
# CPU Queue Size: 341 | IO Queue Size: 21
# Completed I/O-bound task: PID 1752
# Processing I/O-bound task: PID 835
# Completed CPU-bound task: PID 1746
# Processing CPU-bound task: PID 1867
# RL Action: Processing CPU task with PID 1921
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 1760
# RL Action: Processing I/O task with PID 2001
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 1867
# Processing CPU-bound task: PID 1922
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 3287
# RL Action: Processing CPU task with PID 1923
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 844
# CPU Queue Size: 340 | IO Queue Size: 20
# Completed CPU-bound task: PID 1922
# Processing CPU-bound task: PID 1924
# RL Action: Processing CPU task with PID 1925
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 7796
# RL Action: Processing CPU task with PID 1941
# Completed CPU-bound task: PID 1924
# Processing CPU-bound task: PID 1944
# Completed I/O-bound task: PID 7796
# Processing I/O-bound task: PID 9736
# RL Action: Processing I/O task with PID 9737
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 1944
# Processing CPU-bound task: PID 1945
# RL Action: Processing CPU task with PID 1949
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1072
# CPU Queue Size: 336 | IO Queue Size: 19
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# RL Action: Processing CPU task with PID 1957
# Completed CPU-bound task: PID 1945
# Processing CPU-bound task: PID 1958
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 31930
# RL Action: Processing CPU task with PID 1966
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# Completed CPU-bound task: PID 1958
# Processing CPU-bound task: PID 1967
# RL Action: Processing I/O task with PID 1113
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 1254
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1325
# CPU Queue Size: 335 | IO Queue Size: 18
# RL Action: Processing CPU task with PID 1968
# Completed CPU-bound task: PID 1967
# Processing CPU-bound task: PID 1969
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 40797
# RL Action: Processing CPU task with PID 1970
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# Completed CPU-bound task: PID 1969
# Processing CPU-bound task: PID 1989
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 835
# RL Action: Processing CPU task with PID 1997
# Completed I/O-bound task: PID 835
# Processing I/O-bound task: PID 1507
# Completed CPU-bound task: PID 1989
# Processing CPU-bound task: PID 1998
# RL Action: Processing I/O task with PID 1752
# Completed I/O-bound task: PID 1507
# Processing I/O-bound task: PID 1760
# CPU Queue Size: 331 | IO Queue Size: 16
# RL Action: Processing CPU task with PID 2005
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 1998
# Processing CPU-bound task: PID 2029
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 844
# RL Action: Processing CPU task with PID 2030
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 2029
# Processing CPU-bound task: PID 2056
# RL Action: Processing CPU task with PID 2086
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 3287
# RL Action: Processing I/O task with PID 7796
# Completed I/O-bound task: PID 3287
# Processing I/O-bound task: PID 9736
# CPU Queue Size: 329 | IO Queue Size: 15
# Completed CPU-bound task: PID 2056
# Processing CPU-bound task: PID 3075
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 3076
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1072
# Completed CPU-bound task: PID 3075
# Processing CPU-bound task: PID 3283
# RL Action: Processing CPU task with PID 3285
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 31930
# RL Action: Processing CPU task with PID 3325
# Completed CPU-bound task: PID 3283
# Processing CPU-bound task: PID 3326
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# CPU Queue Size: 325 | IO Queue Size: 15
# RL Action: Processing I/O task with PID 835
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 1254
# Completed CPU-bound task: PID 3326
# Processing CPU-bound task: PID 3327
# RL Action: Processing CPU task with PID 3330
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1325
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 40797
# RL Action: Processing CPU task with PID 3333
# Completed CPU-bound task: PID 3327
# Processing CPU-bound task: PID 3334
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 40863
# RL Action: Processing CPU task with PID 3338
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 844
# CPU Queue Size: 326 | IO Queue Size: 14
# Completed CPU-bound task: PID 3334
# Processing CPU-bound task: PID 4728
# Completed I/O-bound task: PID 844
# Processing I/O-bound task: PID 888
# RL Action: Processing I/O task with PID 1507
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 1760
# Completed CPU-bound task: PID 4728
# Processing CPU-bound task: PID 4785
# RL Action: Processing CPU task with PID 4786
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# RL Action: Processing CPU task with PID 7701
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 4785
# Processing CPU-bound task: PID 7773
# CPU Queue Size: 324 | IO Queue Size: 14
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1072
# RL Action: Processing CPU task with PID 7780
# Completed I/O-bound task: PID 1072
# Processing I/O-bound task: PID 1112
# Completed CPU-bound task: PID 7773
# Processing CPU-bound task: PID 7789
# RL Action: Processing I/O task with PID 3287
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 9736
# RL Action: Processing CPU task with PID 7804
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 1254
# Completed CPU-bound task: PID 7789
# Processing CPU-bound task: PID 7806
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 7807
# CPU Queue Size: 322 | IO Queue Size: 13
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 31930
# Completed CPU-bound task: PID 7806
# Processing CPU-bound task: PID 8096
# RL Action: Processing CPU task with PID 8098
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 35298
# Completed I/O-bound task: PID 35298
# Processing I/O-bound task: PID 40797
# RL Action: Processing I/O task with PID 844
# Completed CPU-bound task: PID 8096
# Processing CPU-bound task: PID 8362
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 8363
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 1760
# Completed CPU-bound task: PID 8362
# Processing CPU-bound task: PID 8951
# RL Action: Processing CPU task with PID 9318
# CPU Queue Size: 319 | IO Queue Size: 12
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 40863
# RL Action: Processing CPU task with PID 9321
# Completed CPU-bound task: PID 8951
# Processing CPU-bound task: PID 9332
# Completed I/O-bound task: PID 40863
# Processing I/O-bound task: PID 921
# RL Action: Processing I/O task with PID 1072
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1112
# Completed CPU-bound task: PID 9332
# Processing CPU-bound task: PID 9748
# RL Action: Processing CPU task with PID 9997
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1254
# CPU Queue Size: 317 | IO Queue Size: 11
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 9736
# Completed CPU-bound task: PID 9748
# Processing CPU-bound task: PID 10155
# RL Action: Processing CPU task with PID 10439
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 888
# RL Action: Processing CPU task with PID 10448
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 1325
# Completed CPU-bound task: PID 10155
# Processing CPU-bound task: PID 12298
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 31930
# RL Action: Processing I/O task with PID 35298
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 40797
# Completed CPU-bound task: PID 12298
# Processing CPU-bound task: PID 12509
# RL Action: Processing CPU task with PID 12515
# CPU Queue Size: 314 | IO Queue Size: 10
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 12516
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1112
# Completed CPU-bound task: PID 12509
# Processing CPU-bound task: PID 12517
# Completed I/O-bound task: PID 1112
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 12518
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 12517
# Processing CPU-bound task: PID 12520
# RL Action: Processing I/O task with PID 40863
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 888
# CPU Queue Size: 312 | IO Queue Size: 9
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 1254
# RL Action: Processing CPU task with PID 12521
# Completed CPU-bound task: PID 12520
# Processing CPU-bound task: PID 12522
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1325
# RL Action: Processing CPU task with PID 12523
# Completed I/O-bound task: PID 1325
# Processing I/O-bound task: PID 9736
# Completed CPU-bound task: PID 12522
# Processing CPU-bound task: PID 12525
# RL Action: Processing CPU task with PID 12526
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 31930
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 921
# RL Action: Processing I/O task with PID 1112
# Completed CPU-bound task: PID 12525
# Processing CPU-bound task: PID 12530
# CPU Queue Size: 309 | IO Queue Size: 8
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 12531
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 12530
# Processing CPU-bound task: PID 12532
# RL Action: Processing CPU task with PID 12533
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 40797
# Completed I/O-bound task: PID 40797
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 12532
# Processing CPU-bound task: PID 12534
# RL Action: Processing CPU task with PID 12535
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 1254
# RL Action: Processing I/O task with PID 1325
# CPU Queue Size: 306 | IO Queue Size: 7
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 9736
# Completed CPU-bound task: PID 12534
# Processing CPU-bound task: PID 12583
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 31930
# RL Action: Processing CPU task with PID 12688
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 12583
# Processing CPU-bound task: PID 12689
# RL Action: Processing CPU task with PID 12690
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 16387
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1760
# Completed CPU-bound task: PID 12689
# Processing CPU-bound task: PID 16390
# CPU Queue Size: 304 | IO Queue Size: 7
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# RL Action: Processing I/O task with PID 40797
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 888
# Completed CPU-bound task: PID 16390
# Processing CPU-bound task: PID 16449
# RL Action: Processing CPU task with PID 29756
# Completed I/O-bound task: PID 888
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1254
# RL Action: Processing CPU task with PID 29797
# Completed CPU-bound task: PID 16449
# Processing CPU-bound task: PID 30676
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 9736
# RL Action: Processing CPU task with PID 30799
# CPU Queue Size: 299 | IO Queue Size: 1
# Completed I/O-bound task: PID 9736
# Processing I/O-bound task: PID 31930
# Completed CPU-bound task: PID 30676
# Processing CPU-bound task: PID 30948
# RL Action: Processing I/O task with PID 888
# Completed I/O-bound task: PID 31930
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1254
# RL Action: Processing CPU task with PID 31010
# Completed CPU-bound task: PID 30948
# Processing CPU-bound task: PID 31091
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 1760
# RL Action: Processing CPU task with PID 31092
# Completed I/O-bound task: PID 1760
# Processing I/O-bound task: PID 2084
# Completed CPU-bound task: PID 31091
# Processing CPU-bound task: PID 31104
# CPU Queue Size: 296 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 31224
# Completed I/O-bound task: PID 2084
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# Processing I/O-bound task: PID 1254
# Completed CPU-bound task: PID 31104
# Processing CPU-bound task: PID 31225
# RL Action: Processing I/O task with PID 1760
# Completed I/O-bound task: PID 1254
# Processing I/O-bound task: PID 9736
# RL Action: Processing CPU task with PID 31896
# Completed I/O-bound task: PID 9736
# ...
# RL Action: Processing CPU task with PID 3334
# Completed CPU-bound task: PID 3326
# Processing CPU-bound task: PID 7773
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 7806
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 7773
# Processing CPU-bound task: PID 8362
# RL Action: Processing CPU task with PID 9332
# CPU Queue Size: 70 | IO Queue Size: 0
# Completed CPU-bound task: PID 8362
# Processing CPU-bound task: PID 12298
# RL Action: Processing CPU task with PID 12517
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 12522
# Completed CPU-bound task: PID 12298
# Processing CPU-bound task: PID 12532
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 12583
# Completed CPU-bound task: PID 12532
# Processing CPU-bound task: PID 16390
# CPU Queue Size: 68 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 30676
# Completed CPU-bound task: PID 16390
# Processing CPU-bound task: PID 31104
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 31903
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 31937
# Completed CPU-bound task: PID 31104
# Processing CPU-bound task: PID 32007
# CPU Queue Size: 66 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 34218
# Completed CPU-bound task: PID 32007
# Processing CPU-bound task: PID 35076
# RL Action: Processing CPU task with PID 35084
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 35076
# Processing CPU-bound task: PID 35303
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 35320
# Completed CPU-bound task: PID 35303
# Processing CPU-bound task: PID 35331
# CPU Queue Size: 62 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 35496
# Completed CPU-bound task: PID 35331
# Processing CPU-bound task: PID 35651
# RL Action: Processing CPU task with PID 37120
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 37962
# Completed CPU-bound task: PID 35651
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 39173
# CPU Queue Size: 59 | IO Queue Size: 0
# Completed CPU-bound task: PID 41218
# Processing CPU-bound task: PID 39292
# RL Action: Processing CPU task with PID 41328
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 39292
# Processing CPU-bound task: PID 41331
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41332
# Completed CPU-bound task: PID 41331
# Processing CPU-bound task: PID 39433
# RL Action: Processing CPU task with PID 40795
# CPU Queue Size: 53 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 40802
# Completed CPU-bound task: PID 39433
# Processing CPU-bound task: PID 577
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 40821
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 577
# Processing CPU-bound task: PID 814
# RL Action: Processing CPU task with PID 822
# CPU Queue Size: 50 | IO Queue Size: 0
# Completed CPU-bound task: PID 814
# Processing CPU-bound task: PID 837
# RL Action: Processing CPU task with PID 853
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 865
# Completed CPU-bound task: PID 837
# Processing CPU-bound task: PID 41354
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 881
# Completed CPU-bound task: PID 41354
# Processing CPU-bound task: PID 891
# CPU Queue Size: 46 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 902
# Completed CPU-bound task: PID 891
# Processing CPU-bound task: PID 934
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 956
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 934
# Processing CPU-bound task: PID 965
# RL Action: Processing CPU task with PID 1059
# CPU Queue Size: 44 | IO Queue Size: 0
# Completed CPU-bound task: PID 965RL Action: Processing CPU task with PID 1068
#
# Processing CPU-bound task: PID 1080
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1114
# Completed CPU-bound task: PID 1080
# Processing CPU-bound task: PID 1127
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1136
# Completed CPU-bound task: PID 1127
# Processing CPU-bound task: PID 1170
# CPU Queue Size: 40 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 1178
# Completed CPU-bound task: PID 1170
# Processing CPU-bound task: PID 1197
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1209
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 1197
# Processing CPU-bound task: PID 1230
# RL Action: Processing CPU task with PID 1248
# CPU Queue Size: 41 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 1284
# Completed CPU-bound task: PID 1230
# Processing CPU-bound task: PID 1307
# RL Action: Processing CPU task with PID 1368
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 1307
# Processing CPU-bound task: PID 1564
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41282
# Completed CPU-bound task: PID 1564
# Processing CPU-bound task: PID 1617
# CPU Queue Size: 42 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 1730
# RL Action: Processing CPU task with PID 1944
# Completed CPU-bound task: PID 1617
# Processing CPU-bound task: PID 3075
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 3326
# Completed CPU-bound task: PID 3075
# Processing CPU-bound task: PID 7773
# RL Action: Processing CPU task with PID 8362
# CPU Queue Size: 39 | IO Queue Size: 0
# Completed CPU-bound task: PID 7773
# Processing CPU-bound task: PID 41386
# RL Action: Processing CPU task with PID 41387
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 41386
# Processing CPU-bound task: PID 12298
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 12532
# Completed CPU-bound task: PID 12298
# Processing CPU-bound task: PID 16390
# RL Action: Processing CPU task with PID 31104
# CPU Queue Size: 35 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 32007
# Completed CPU-bound task: PID 16390
# Processing CPU-bound task: PID 35076
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 35303
# Completed CPU-bound task: PID 35076
# Processing CPU-bound task: PID 35331
# RL Action: Processing CPU task with PID 35651
# CPU Queue Size: 33 | IO Queue Size: 0
# Completed CPU-bound task: PID 35331
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 39292
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# Processing CPU-bound task: PID 39433
# RL Action: Processing CPU task with PID 41331
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 577
# Completed CPU-bound task: PID 39433
# Processing CPU-bound task: PID 814
# CPU Queue Size: 29 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 837
# Completed CPU-bound task: PID 814
# Processing CPU-bound task: PID 891
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41354
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 891
# Processing CPU-bound task: PID 934
# RL Action: Processing CPU task with PID 965
# CPU Queue Size: 27 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 1080
# Completed CPU-bound task: PID 934
# Processing CPU-bound task: PID 1127
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1170
# Completed CPU-bound task: PID 1127
# Processing CPU-bound task: PID 41407
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41408
# Completed CPU-bound task: PID 41407
# Processing CPU-bound task: PID 41409
# CPU Queue Size: 23 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 1197
# Completed CPU-bound task: PID 41409
# Processing CPU-bound task: PID 1230
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41410
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41411
# Completed CPU-bound task: PID 1230
# Processing CPU-bound task: PID 41412
# CPU Queue Size: 21 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 41413
# Completed CPU-bound task: PID 41412
# Processing CPU-bound task: PID 41414
# RL Action: Processing CPU task with PID 1307
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 41414
# Processing CPU-bound task: PID 1564
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1617
# Completed CPU-bound task: PID 1564
# Processing CPU-bound task: PID 41419
# CPU Queue Size: 16 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 3075
# Completed CPU-bound task: PID 41419
# Processing CPU-bound task: PID 7773
# RL Action: Processing CPU task with PID 12298
# Processing I/O-bound task: PID 921
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 16390
# Completed CPU-bound task: PID 7773
# Processing CPU-bound task: PID 35076
# CPU Queue Size: 12 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 35331
# Completed CPU-bound task: PID 35076
# Processing CPU-bound task: PID 814
# RL Action: Processing CPU task with PID 39433
# Processing I/O-bound task: PID 921
# Completed CPU-bound task: PID 814
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 891
# RL Action: Processing CPU task with PID 934
# Completed CPU-bound task: PID 41218
# Processing CPU-bound task: PID 1127
# CPU Queue Size: 7 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 41407
# Completed CPU-bound task: PID 1127
# Processing CPU-bound task: PID 1230
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1564
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 1230
# Processing CPU-bound task: PID 41419
# RL Action: Processing CPU task with PID 7773
# CPU Queue Size: 5 | IO Queue Size: 0
# Completed CPU-bound task: PID 41419
# Processing CPU-bound task: PID 35076
# RL Action: Processing CPU task with PID 814
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 1127
# Completed CPU-bound task: PID 35076
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41468
# CPU Queue Size: 5 | IO Queue Size: 0Completed CPU-bound task: PID 41218
# Processing CPU-bound task: PID 1230
#
# RL Action: Processing CPU task with PID 41419
# Completed CPU-bound task: PID 1230
# Processing CPU-bound task: PID 41470
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41471
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41470
# Processing CPU-bound task: PID 41472
# RL Action: Processing CPU task with PID 1230
# CPU Queue Size: 2 | IO Queue Size: 0
# RL Action: Processing CPU task with PID 35076
# Completed CPU-bound task: PID 41472
# Processing CPU-bound task: PID 41218
# Processing I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41470
# Completed CPU-bound task: PID 41218
# Processing CPU-bound task: PID 41472
# Completed I/O-bound task: PID 921
# CPU Queue Size: 0 | IO Queue Size: 0
# Completed CPU-bound task: PID 41472
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# RL Action: Processing CPU task with PID 41472
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# RL Action: Processing CPU task with PID 41473
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41474
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 41475
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing CPU-bound task: PID 41218Processing I/O-bound task: PID 921
#
# RL Action: Processing CPU task with PID 41485
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 41502
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# RL Action: Processing CPU task with PID 41503
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 41504
# Completed I/O-bound task: PID 921
# RL Action: Processing CPU task with PID 41505
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# RL Action: Processing CPU task with PID 41506
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921Processing CPU-bound task: PID 41218
#
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# CPU Queue Size: 0 | IO Queue Size: 0
# Processing I/O-bound task: PID 921
# Processing CPU-bound task: PID 41218
#
# Stopping program...
# Completed I/O-bound task: PID 921
# Completed CPU-bound task: PID 41218
# All threads stopped.

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from process_scheduler import ProcessSchedulingEnv  # Import your custom environment


env = ProcessSchedulingEnv()


model = PPO("MlpPolicy", env, learning_rate=0.001, verbose=1)


model.learn(total_timesteps=100000)

model.save("rl_scheduler_model")

print("Model saved as rl_scheduler_model.zip")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.1     |
# |    ep_rew_mean     | -339     |
# | time/              |          |
# |    fps             | 6732     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | -248        |
# | time/                   |             |
# |    fps                  | 4836        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017851986 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.00346     |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.4e+04     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 3.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.3        |
# |    ep_rew_mean          | -215        |
# | time/                   |             |
# |    fps                  | 4176        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018633952 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.0409      |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.62e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 1.79e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 3740        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.024552286 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.75e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 7.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.3        |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 3314        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.055862684 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.001       |
# |    loss                 | 340         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 12.1      |
# |    ep_rew_mean          | -123      |
# | time/                   |           |
# |    fps                  | 2941      |
# |    iterations           | 6         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0310723 |
# |    clip_fraction        | 0.138     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.361    |
# |    explained_variance   | 0.288     |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.14e+03  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.00754  |
# |    value_loss           | 4.84e+03  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13           |
# |    ep_rew_mean          | -114         |
# | time/                   |              |
# |    fps                  | 2606         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0068229744 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 2370        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009223709 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.18       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.001       |
# |    loss                 | 528         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.5         |
# |    ep_rew_mean          | -114         |
# | time/                   |              |
# |    fps                  | 2207         |
# |    iterations           | 9            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0026125272 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.159       |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.001        |
# |    loss                 | 496          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000661     |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.1         |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 2096         |
# |    iterations           | 10           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0075163096 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.581        |
# |    learning_rate        | 0.001        |
# |    loss                 | 308          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000915     |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.6         |
# |    ep_rew_mean          | -85.1        |
# | time/                   |              |
# |    fps                  | 2019         |
# |    iterations           | 11           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0046646483 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.001        |
# |    loss                 | 48.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00208      |
# |    value_loss           | 616          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.1        |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 1961        |
# |    iterations           | 12          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012461858 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.001       |
# |    loss                 | 161         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 299         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.7         |
# |    ep_rew_mean          | -161         |
# | time/                   |              |
# |    fps                  | 1913         |
# |    iterations           | 13           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0059358976 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.143       |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.00124      |
# |    value_loss           | 4.13e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.8       |
# |    ep_rew_mean          | -104       |
# | time/                   |            |
# |    fps                  | 1864       |
# |    iterations           | 14         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00213148 |
# |    clip_fraction        | 0.0376     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.153     |
# |    explained_variance   | 0.481      |
# |    learning_rate        | 0.001      |
# |    loss                 | 108        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00016   |
# |    value_loss           | 4.13e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.6         |
# |    ep_rew_mean          | -97.7        |
# | time/                   |              |
# |    fps                  | 1827         |
# |    iterations           | 15           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0018170798 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.001        |
# |    loss                 | 859          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 1.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | -99.5       |
# | time/                   |             |
# |    fps                  | 1796        |
# |    iterations           | 16          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.036786467 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0951     |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.001       |
# |    loss                 | 119         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0043      |
# |    value_loss           | 358         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | -98.1      |
# | time/                   |            |
# |    fps                  | 1774       |
# |    iterations           | 17         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00501768 |
# |    clip_fraction        | 0.025      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0908    |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.001      |
# |    loss                 | 442        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00153    |
# |    value_loss           | 542        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | -92         |
# | time/                   |             |
# |    fps                  | 1758        |
# |    iterations           | 18          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.045378707 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.075      |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.001       |
# |    loss                 | 15.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000182    |
# |    value_loss           | 587         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | -133       |
# | time/                   |            |
# |    fps                  | 1746       |
# |    iterations           | 19         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.08441283 |
# |    clip_fraction        | 0.0539     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0858    |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.001      |
# |    loss                 | 74.7       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000111  |
# |    value_loss           | 401        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 1731         |
# |    iterations           | 20           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0011922964 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.096       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.001        |
# |    loss                 | 123          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000465    |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 1716        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012225461 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.001       |
# |    loss                 | 660         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -3.22e-05   |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.3         |
# |    ep_rew_mean          | -94.8        |
# | time/                   |              |
# |    fps                  | 1702         |
# |    iterations           | 22           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0025516725 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.083       |
# |    explained_variance   | 0.667        |
# |    learning_rate        | 0.001        |
# |    loss                 | 55.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00258      |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 1689        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009898476 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0812     |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.001       |
# |    loss                 | 33.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00438     |
# |    value_loss           | 678         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.1         |
# |    ep_rew_mean          | -99          |
# | time/                   |              |
# |    fps                  | 1676         |
# |    iterations           | 24           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0050199972 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.08        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.001        |
# |    loss                 | 307          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00314      |
# |    value_loss           | 768          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13           |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 25           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0075793792 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0692      |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.001        |
# |    loss                 | 86.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00078      |
# |    value_loss           | 183          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.6         |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 1657         |
# |    iterations           | 26           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0021994896 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0678      |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.8e+03      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.00518      |
# |    value_loss           | 832          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | -96.2       |
# | time/                   |             |
# |    fps                  | 1649        |
# |    iterations           | 27          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018152822 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0716     |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.001       |
# |    loss                 | 58          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00209     |
# |    value_loss           | 239         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.2         |
# |    ep_rew_mean          | -94.4        |
# | time/                   |              |
# |    fps                  | 1642         |
# |    iterations           | 28           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0073435577 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0703      |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.001        |
# |    loss                 | 54.6         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.0062       |
# |    value_loss           | 227          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.7         |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 1633         |
# |    iterations           | 29           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0008421502 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0664      |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.001        |
# |    loss                 | 28.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000338    |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.6        |
# |    ep_rew_mean          | -88.7       |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 30          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.034134593 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0761     |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.001       |
# |    loss                 | 43          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00223     |
# |    value_loss           | 258         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.3         |
# |    ep_rew_mean          | -99.5        |
# | time/                   |              |
# |    fps                  | 1620         |
# |    iterations           | 31           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0061558383 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0696      |
# |    explained_variance   | 0.737        |
# |    learning_rate        | 0.001        |
# |    loss                 | 116          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00121      |
# |    value_loss           | 737          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.2         |
# |    ep_rew_mean          | -97.5        |
# | time/                   |              |
# |    fps                  | 1615         |
# |    iterations           | 32           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0015730414 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0619      |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.001        |
# |    loss                 | 126          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.000367     |
# |    value_loss           | 206          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.4        |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 33          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007981379 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.067      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.001       |
# |    loss                 | 61.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00292     |
# |    value_loss           | 608         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.2       |
# |    ep_rew_mean          | -103       |
# | time/                   |            |
# |    fps                  | 1605       |
# |    iterations           | 34         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.02636238 |
# |    clip_fraction        | 0.0744     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0581    |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.001      |
# |    loss                 | 37.9       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0595     |
# |    value_loss           | 168        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.3         |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 35           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0017759581 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0608      |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.001        |
# |    loss                 | 38.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 184          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.3        |
# |    ep_rew_mean          | -119        |
# | time/                   |             |
# |    fps                  | 1589        |
# |    iterations           | 36          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003185063 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0736     |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.001       |
# |    loss                 | 137         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000516   |
# |    value_loss           | 472         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.7         |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 37           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0016545968 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0814      |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.001        |
# |    loss                 | 774          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 602          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.5         |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1585         |
# |    iterations           | 38           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0021139868 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0808      |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.001        |
# |    loss                 | 57.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 39          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.001337416 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0625     |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.001       |
# |    loss                 | 321         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 477         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -114         |
# | time/                   |              |
# |    fps                  | 1581         |
# |    iterations           | 40           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0029940102 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0643      |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 0.001        |
# |    loss                 | 255          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 288          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.7         |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 1576         |
# |    iterations           | 41           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0008221448 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0687      |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.001        |
# |    loss                 | 677          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 386          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.1         |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 1574         |
# |    iterations           | 42           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0050145877 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0753      |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.001        |
# |    loss                 | 819          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00413      |
# |    value_loss           | 590          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.3        |
# |    ep_rew_mean          | -98.3       |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 43          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005466042 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0992     |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.001       |
# |    loss                 | 142         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 1.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | -97.1       |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 44          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.038094543 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0769     |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.001       |
# |    loss                 | 136         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 976         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.4         |
# |    ep_rew_mean          | -103         |
# | time/                   |              |
# |    fps                  | 1565         |
# |    iterations           | 45           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018847152 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0623      |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.001        |
# |    loss                 | 68           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.0026       |
# |    value_loss           | 243          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 1563        |
# |    iterations           | 46          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006267597 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0682     |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.001       |
# |    loss                 | 92          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000329    |
# |    value_loss           | 137         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.8         |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 1561         |
# |    iterations           | 47           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0015378018 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0632      |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.001        |
# |    loss                 | 118          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.00019      |
# |    value_loss           | 177          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.3        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 48          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012684736 |
# |    clip_fraction        | 0.0247      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0646     |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.001       |
# |    loss                 | 51.5        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00068     |
# |    value_loss           | 218         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.3         |
# |    ep_rew_mean          | -99.4        |
# | time/                   |              |
# |    fps                  | 1557         |
# |    iterations           | 49           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0059489366 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0619      |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 0.001        |
# |    loss                 | 117          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000538     |
# |    value_loss           | 209          |
# ------------------------------------------
# Training complete. Model saved as rl_scheduler_model.zip

# %%
import threading
import time
import csv
import psutil
import pandas as pd
import joblib
from queue import Queue

# Load trained ML model
model = joblib.load("process_classifier.pkl")

# Define Queues
cpu_queue = Queue()
io_queue = Queue()
processed_pids = set()
running = True  


# RL-related variables
state_space = ['CPU_QUEUE_SIZE', 'IO_QUEUE_SIZE']
action_space = ['PROCESS_CPU', 'PROCESS_IO']
count = 0 
last_action = None
# RL Metrics Dictionary
rl_metrics = {
    "decision_steps": 0,
    "total_reward": 0,
    "action_counts": {"PROCESS_CPU": 0, "PROCESS_IO": 0},
    "completed_tasks": {"CPU": 0, "IO": 0}
}

# Placeholder function for RL agent's decision-making
def rl_decision(state):
    global count
    if count == 3:
        count = 0
        return 'PROCESS_IO'
    elif state['CPU_QUEUE_SIZE'] > state['IO_QUEUE_SIZE']:
        count += 1
        return 'PROCESS_CPU'
    else:
        return 'PROCESS_IO'

# Classify and enqueue processes
def classify_and_enqueue():
    global processed_pids, running
    while running:
        for proc in psutil.process_iter(['pid']):
            if not running:
                break
            try:
                pid = proc.info['pid']
                if pid in processed_pids:
                    continue

                
                process_data = pd.DataFrame([{
                    "utime": proc.cpu_times().user if proc.cpu_times() else 0,
                    "stime": proc.cpu_times().system if proc.cpu_times() else 0,
                    "priority": proc.nice(),
                    "mem_usage": proc.memory_info().rss if proc.memory_info() else 0
                }])

                
                prediction = model.predict(process_data)[0]

                
                if prediction:
                    cpu_queue.put(pid)
                else:
                    io_queue.put(pid)

                processed_pids.add(pid)  
            except (psutil.NoSuchProcess, psutil.AccessDenied):
                continue
        time.sleep(5)


def process_queue(q, queue_type, execution_time=2):
    global processed_pids, running
    while running:
        if not q.empty():
            pid = q.get()
            if not psutil.pid_exists(pid):
                print(f"Skipping {queue_type} task (PID {pid} no longer exists)")
                continue

            print(f"Processing {queue_type} task: PID {pid}")
            time.sleep(execution_time)
            processed_pids.discard(pid)
            q.task_done()
            print(f"Completed {queue_type} task: PID {pid}")
        else:
            time.sleep(1)


def get_reward(state, last_action):
    reward = 0

   
    if last_action == "PROCESS_CPU":
        reward += 10  
        if state['CPU_QUEUE_SIZE'] > 100:  
            reward += 10  
        if state['CPU_QUEUE_SIZE'] > 500:  
            reward += 20 
        if state['IO_QUEUE_SIZE'] < 20:  
            reward += 5  
    
    
    if last_action == "PROCESS_IO":
        reward += 15  
        if state['IO_QUEUE_SIZE'] > 20:
            reward += 10  
        if state['IO_QUEUE_SIZE'] > 50:
            reward += 20  

    
    if state['CPU_QUEUE_SIZE'] > 500:
        reward -= 5 
    
   
    if state['IO_QUEUE_SIZE'] > 50:
        reward -= 15  

    return reward

# RL Scheduling and Queue Management
def schedule_and_manage_queues():
    global running
    global last_action
    while running:
        state = {
            'CPU_QUEUE_SIZE': cpu_queue.qsize(),
            'IO_QUEUE_SIZE': io_queue.qsize()
        }

        action = rl_decision(state)
        
        if action == 'PROCESS_CPU' and not cpu_queue.empty():
            pid = cpu_queue.get()
            print(f"RL Action: Processing CPU task with PID {pid}")
            time.sleep(2)
            cpu_queue.task_done()
            reward = get_reward(state,last_action)
            rl_metrics["total_reward"] += reward
            rl_metrics["decision_steps"] += 1
            rl_metrics["action_counts"]["PROCESS_CPU"] += 1
            rl_metrics["completed_tasks"]["CPU"] += 1
            last_action = 'PROCESS_CPU'

        elif action == 'PROCESS_IO' and not io_queue.empty():
            pid = io_queue.get()
            print(f"RL Action: Processing I/O task with PID {pid}")
            time.sleep(1)
            io_queue.task_done()
            reward = get_reward(state,last_action)
            rl_metrics["total_reward"] += reward
            rl_metrics["decision_steps"] += 1
            rl_metrics["action_counts"]["PROCESS_IO"] += 1
            rl_metrics["completed_tasks"]["IO"] += 1
            last_action = 'PROCESS_IO'

        time.sleep(1)


def log_rl_metrics():
    """ Periodically logs RL agent metrics into a CSV file """
    with open("rl_metrics_log.csv", "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Time", "Steps", "PROCESS_CPU", "PROCESS_IO", "Total Reward", "Avg Reward", "CPU Queue", "IO Queue"])

    while running:
        print("Logging metrics...") 

        if rl_metrics["decision_steps"] > 0:
            avg_reward = rl_metrics["total_reward"] / rl_metrics["decision_steps"]
        else:
            avg_reward = 0

        with open("rl_metrics_log.csv", "a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([
                time.strftime("%H:%M:%S"), rl_metrics["decision_steps"], 
                rl_metrics["action_counts"]["PROCESS_CPU"], 
                rl_metrics["action_counts"]["PROCESS_IO"],
                rl_metrics["total_reward"], avg_reward,
                cpu_queue.qsize(), io_queue.qsize()
            ])
            file.flush()  

        time.sleep(5) 

# Start Worker Threads
cpu_worker = threading.Thread(target=process_queue, args=(cpu_queue, "CPU-bound", 2), daemon=True)
io_worker = threading.Thread(target=process_queue, args=(io_queue, "I/O-bound", 1), daemon=True)
classifier_thread = threading.Thread(target=classify_and_enqueue, daemon=True)
scheduler_thread = threading.Thread(target=schedule_and_manage_queues, daemon=True)
log_metrics_thread = threading.Thread(target=log_rl_metrics, daemon=True)  # Logging thread

# Start all threads
cpu_worker.start()
io_worker.start()
classifier_thread.start()
scheduler_thread.start()
log_metrics_thread.start()


try:
    while True:
        print(f"CPU Queue Size: {cpu_queue.qsize()} | IO Queue Size: {io_queue.qsize()}")
        time.sleep(5)
except KeyboardInterrupt:
    print("\nStopping program...")
    running = False 
    classifier_thread.join()
    cpu_worker.join()
    io_worker.join()
    scheduler_thread.join()
    log_metrics_thread.join()
    print("All threads stopped.")
# Out:
# ✅ RL Model Loaded Successfully!
# CPU Queue Size: 0 | IO Queue Size: 0
# Logging metrics...
# Processing CPU-bound task: PID 577Processing I/O-bound task: PID 824
#
# RL Action: Processing CPU task with PID 804
# Completed I/O-bound task: PID 824
# Processing I/O-bound task: PID 835
#
# Stopping program...
# Completed I/O-bound task: PID 835
# Completed CPU-bound task: PID 577
# All threads stopped.

# %% [markdown]
# ## Perform metrics

# %%
import psutil
import pandas as pd

def get_windows_process_data():
    """ Collects process data from Windows for evaluation. """
    process_list = []
    
    for proc in psutil.process_iter(attrs=['pid', 'cpu_times', 'memory_info', 'nice']):
        try:
            info = proc.info
            process_list.append({
                "pid": info['pid'],
                "utime": info['cpu_times'].user if info['cpu_times'] else 0,  # User mode CPU time
                "stime": info['cpu_times'].system if info['cpu_times'] else 0,  # Kernel mode CPU time
                "priority": info['nice'],  # Process priority
                "mem_usage": info['memory_info'].rss if info['memory_info'] else 0  # Memory usage in bytes
            })
        except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
            continue

    return pd.DataFrame(process_list)

# Get real-time Windows process data
df_test = get_windows_process_data()
df_test.to_csv("windows_test_data2.csv", index=False)  # Save for reuse

# %%
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


model = joblib.load("process_classifier.pkl")


df_test = pd.read_csv("windows_process_data.csv")


X_test = df_test.drop(columns=["pid"])

# %%
y_pred = model.predict(X_test)
df_test["predicted_class"] = y_pred
print(df_test.head())
# Out:
#    pid  utime  stime  priority  mem_usage  predicted_class
# 0    0    0.0    0.0         0          0            False
# 1    1    0.0    0.0         0          0            False
# 2  505    0.0    0.0         0          0            False
# 3  506    0.0    0.0         0          0            False
# 4  507    0.0    0.0         0          0            False

# %%
df_test["true_label"] = df_test.apply(lambda row: 1 if row["utime"] + row["stime"] > 0.5 else 0, axis=1)


y_test = df_test["true_label"]

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_test["true_label"] = df_test.apply(lambda row: 1 if row["utime"] + row["stime"] > 0.5 else 0, axis=1)
#       4 y_test = df_test["true_label"]
#       6 print("Classification Report:")
#
# NameError: name 'df_test' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["I/O-Bound", "CPU-Bound"], yticklabels=["I/O-Bound", "CPU-Bound"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (Windows Process Classification)")
plt.show()

# %% [markdown]
# # DEBUGGING REQ

# %%
import pandas as pd

def evaluate_rl_agent(csv_file):
    """ Computes RL agent performance metrics from log data """
    
    df = pd.read_csv(csv_file)
    
    
    
    # Convert necessary columns to integers/floats
    int_cols = ["PROCESS_CPU", "PROCESS_IO", "Steps", "CPU Queue", "IO Queue"]
    float_cols = ["Avg Reward"]
    df[int_cols] = df[int_cols].astype(int)
    df[float_cols] = df[float_cols].astype(float)

    # Calculate key metrics
    total_actions = df["Steps"].sum() 
    cpu_actions = df["PROCESS_CPU"].sum()
    io_actions = df["PROCESS_IO"].sum()

    # Efficiency metrics
    cpu_utilization = (cpu_actions / total_actions) * 100 
    io_utilization = (io_actions / total_actions) * 100 

    # Queue balance ratio
    if len(df) >= 2:
        final_cpu_queue = df.iloc[-1:]["CPU Queue"].mean()
        final_io_queue = df.iloc[-1:]["IO Queue"].mean()
        queue_balance = final_cpu_queue / (final_io_queue + 1)  # Avoid division by zero
    else:
        queue_balance = None

    # Average Reward Analysis
    avg_reward = df["Avg Reward"].mean() if not df.empty else 0
    max_reward = df["Avg Reward"].max() if not df.empty else 0
    min_reward = df["Avg Reward"].min() if not df.empty else 0

    # Processing Rate (actions per time step)
    processing_rate = total_actions / len(df) if len(df) > 0 else 0

    # Display Results
    print(" RL Agent Evaluation Metrics:")
    print(f"Total Actions Taken: {total_actions}")
    print(f"CPU Actions Processed: {cpu_actions} ({cpu_utilization:.2f}%)")
    print(f"IO Actions Processed: {io_actions} ({io_utilization:.2f}%)")
    print(f"Queue Balance (CPU/IO Ratio): {queue_balance if queue_balance is not None else 'N/A'}")
    print(f"Average Reward: {avg_reward:.2f} (Min: {min_reward}, Max: {max_reward})")
    print(f"Processing Rate: {processing_rate:.2f} actions per step")

# %%
df = pd.read_csv("rl_metrics_log.csv")
df.columns
# Out:
# Index(['Time', 'Steps', 'PROCESS_CPU', 'PROCESS_IO', 'Total Reward',
#        'Avg Reward', 'CPU Queue', 'IO Queue'],
#       dtype='object')

# %%
df = pd.read_csv("rl_metrics_log.csv")
df.columns = df.columns.str.strip()  # Trim spaces from column names
print("🔍 CSV Head:\n", df.head())  # Inspect initial data

df = df.apply(pd.to_numeric, errors='coerce')  # Convert safely
print("🔍 Data Types:\n", df.dtypes)  # Check types

print("🔍 Steps Column Stats:\n", df["Steps"].describe())  # Check if Steps has meaningful values

df.fillna(0, inplace=True)  # Replace NaNs with zeros
# Out:
# 🔍 CSV Head:
#         Time  Steps  PROCESS_CPU  PROCESS_IO  Total Reward  Avg Reward  \
# 0  23:20:30      0            0           0             0    0.000000
# 1  23:20:35      2            2           0             5    2.500000
# 2  23:20:40      4            3           1            15    3.750000
# 3  23:20:45      5            4           1            45    9.000000
# 4  23:20:50      7            6           1            55    7.857143
#
#    CPU Queue  IO Queue
# 0         27         3
# 1        446        68
# 2        446        67
# 3        444        67
# 4        443        66
# 🔍 Data Types:
#  Time            float64
# Steps             int64
# PROCESS_CPU       int64
# PROCESS_IO        int64
# Total Reward      int64
# Avg Reward      float64
# CPU Queue         int64
# IO Queue          int64
# dtype: object
# 🔍 Steps Column Stats:
#  count    190.000000
# mean     170.073684
# std       98.081948
# min        0.000000
# 25%       85.500000
# 50%      171.000000
# 75%      256.750000
# max      331.000000
# Name: Steps, dtype: float64

# %%
total_actions = df["Steps"].sum() 
cpu_actions = df["PROCESS_CPU"].sum()
io_actions = df["PROCESS_IO"].sum()
cpu_utilization = (cpu_actions / total_actions) * 100
print(cpu_utilization)
# Out:
# 75.96707309525283

# %%
evaluate_rl_agent("rl_metrics_log.csv")
# Out:
# 🚀 RL Agent Evaluation Metrics:
# 🔹 Total Actions Taken: 32314
# 🔹 CPU Actions Processed: 24548 (75.97%)
# 🔹 IO Actions Processed: 7766 (24.03%)
# 🔹 Queue Balance (CPU/IO Ratio): 217.0
# 🔹 Average Reward: 15.38 (Min: 0.0, Max: 19.71299093655589)
# 🔹 Processing Rate: 170.07 actions per step

# %%
import psutil

def get_process_metrics(pid):
    try:
        p = psutil.Process(pid)
        with p.oneshot():
            return {
                "pid": pid,
                "cpu_percent": p.cpu_percent(interval=0.1),
                "mem_usage": p.memory_info().rss / (1024 * 1024),  # Convert to MB
                "io_read_bytes": p.io_counters().read_bytes,
                "io_write_bytes": p.io_counters().write_bytes,
                "voluntary_ctx_switches": p.num_ctx_switches().voluntary,
            }
    except psutil.AccessDenied:
        print(f"Permission denied for PID {pid}. Skipping...")
        return None
    except psutil.NoSuchProcess:
        return None

def main():
    for proc in psutil.process_iter(attrs=['pid']):
        metrics = get_process_metrics(proc.info['pid'])
        if metrics:
            print(metrics)

if __name__ == "__main__":
    main()
# Out:
# Permission denied for PID 0. Skipping...
# Permission denied for PID 1. Skipping...
# Permission denied for PID 505. Skipping...
# Permission denied for PID 506. Skipping...
# Permission denied for PID 507. Skipping...
# Permission denied for PID 509. Skipping...
# Permission denied for PID 510. Skipping...
# Permission denied for PID 513. Skipping...
# Permission denied for PID 516. Skipping...
# Permission denied for PID 517. Skipping...
# Permission denied for PID 518. Skipping...
# Permission denied for PID 519. Skipping...
# Permission denied for PID 521. Skipping...
# Permission denied for PID 523. Skipping...
# Permission denied for PID 525. Skipping...
# Permission denied for PID 526. Skipping...
# Permission denied for PID 528. Skipping...
# Permission denied for PID 532. Skipping...
# Permission denied for PID 533. Skipping...
# Permission denied for PID 534. Skipping...
# Permission denied for PID 535. Skipping...
# Permission denied for PID 538. Skipping...
# Permission denied for PID 539. Skipping...
# Permission denied for PID 542. Skipping...
# Permission denied for PID 543. Skipping...
# Permission denied for PID 545. Skipping...
# Permission denied for PID 546. Skipping...
# Permission denied for PID 547. Skipping...
# Permission denied for PID 548. Skipping...
# Permission denied for PID 549. Skipping...
# Permission denied for PID 552. Skipping...
# Permission denied for PID 554. Skipping...
# Permission denied for PID 555. Skipping...
# Permission denied for PID 557. Skipping...
# Permission denied for PID 558. Skipping...
# Permission denied for PID 560. Skipping...
# Permission denied for PID 561. Skipping...
# Permission denied for PID 562. Skipping...
# Permission denied for PID 563. Skipping...
# Permission denied for PID 564. Skipping...
# Permission denied for PID 567. Skipping...
# Permission denied for PID 568. Skipping...
# Permission denied for PID 569. Skipping...
# Permission denied for PID 570. Skipping...
# Permission denied for PID 571. Skipping...
# Permission denied for PID 572. Skipping...
# Permission denied for PID 573. Skipping...
# Permission denied for PID 574. Skipping...
# Permission denied for PID 575. Skipping...
# Permission denied for PID 576. Skipping...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 28
#      25             print(metrics)
#      27 if __name__ == "__main__":
# ---> 28     main()
#
# Cell In[2], line 23, in main()
#      21 def main():
#      22     for proc in psutil.process_iter(attrs=['pid']):
# ---> 23         metrics = get_process_metrics(proc.info['pid'])
#      24         if metrics:
#      25             print(metrics)
#
# Cell In[2], line 11, in get_process_metrics(pid)
#       5     p = psutil.Process(pid)
#       6     with p.oneshot():
#       7         return {
#       8             "pid": pid,
#       9             "cpu_percent": p.cpu_percent(interval=0.1),
#      10             "mem_usage": p.memory_info().rss / (1024 * 1024),  # Convert to MB
# ---> 11             "io_read_bytes": p.io_counters().read_bytes,
#      12             "io_write_bytes": p.io_counters().write_bytes,
#      13             "voluntary_ctx_switches": p.num_ctx_switches().voluntary,
#      14         }
#      15 except psutil.AccessDenied:
#      16     print(f"Permission denied for PID {pid}. Skipping...")
#
# AttributeError: 'Process' object has no attribute 'io_counters'
